# %% [markdown]
# <a href="https://colab.research.google.com/github/maekuhi/NeuralNetworks/blob/main/TestNew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I am writing this notebook to test the cycle

# %% [markdown]
# # New Section

# %% [markdown]
# After save

# %% [markdown]
# rev1
